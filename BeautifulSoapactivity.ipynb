# %% [markdown]
# <a href="https://colab.research.google.com/github/jbtuku/Data-Gathering/blob/main/BeautifulSoapactivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
print (html)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
text = soup.get_text()
print(text)
# Out:
# Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2017 Intel Great Place to Run 10K \ Urban Clash Games
#  Hillsboro Stadium, Hillsboro, OR
#  June 2nd, 2017
#
#
#
#
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
#
#
#
#
#
# Huber Timing Home
#
#
#
#
#
# 10K:
#
#
# Finishers:
# 577
#
#
# Male:
# 414
#
#
# Female:
# 163
#
#
#
#
#
#
#
#
#
#
#  5K Individual
#  5K Team
#  10K Individual
#  10K Team
#  Summary
#
#
#
#
# Indvidual Results
#
#
#
# 10K Results
#
#
#
# Search:
#
# Search
# Division:
#
# Men
# Women
# Non-Binary
# Masters Men
# Masters Women
# Masters Non-Binary
#
# F 18-25
# F 26-35
# F 36-45
# F 46-55
# F Under 18
# M 18-25
# M 26-35
# M 36-45
# M 46-55
# M 55+
# M Under 18
#  Team:
#
# Unattached
# COLUMBIA TEAM A
# COLUMBIA TEAM B
# COLUMBIA TEAM C
# COLUMBIA TEAM D
# COLUMBIA TEAM E
# DTNA1
# DTNA2
# DTNA3
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/

# %%
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>
# ...

# %%
print("Total rows found:", len(rows))
print("Here are the first 10 row tags:")
for i, row in enumerate(rows[:10]):
    print(f"\nRow {i+1}:")
    print(row)
# Out:
# Total rows found: 582
# Here are the first 10 row tags:
#
# Row 1:
# <tr colspan="2">
# <b>10K:</b>
# </tr>
#
# Row 2:
# <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>
#
# Row 3:
# <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>
#
# Row 4:
# <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>
#
# Row 5:
# <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>
#
# Row 6:
# <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>
#
# Row 7:
# <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# ...

# %%
for row in rows:
    row_td = row.find_all('td')

print(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>1:42:10</td>, <td></td>]

# %%
type(row_td)
# Out:
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]

# %%
cleantext = ', '.join([BeautifulSoup(str(cell), "lxml").get_text(strip=True) for cell in row_td])
print(cleantext)
# Out:
# 577, 443, LIBBY B MITCHELL, F, HILLSBORO, OR, 1:41:18, 1:42:10,

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))

    clean2 = clean2.replace('\n', ' ').replace('\r', ' ')
    clean2 = ' '.join(clean2.split())
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443, LIBBY B MITCHELL , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, JARED WILSON , M, TIGARD, OR, 36:21, ...
# 6  [2, 573, NATHAN A SUSTERSIC , M, PORTLAND, OR,...
# 7  [3, 687, FRANCISCO MAYA , M, PORTLAND, OR, 37:...
# 8  [4, 623, PAUL MORROW , M, BEAVERTON, OR, 38:34...
# 9  [5, 569, DEREK G OSBORNE , M, HILLSBORO, OR, 3...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0      1                     2     3           4     5       6  \
# 0           []   None                  None  None        None  None    None
# 1  [Finishers:   577]                  None  None        None  None    None
# 2       [Male:   414]                  None  None        None  None    None
# 3     [Female:   163]                  None  None        None  None    None
# 4           []   None                  None  None        None  None    None
# 5           [1    814         JARED WILSON      M      TIGARD    OR   36:21
# 6           [2    573   NATHAN A SUSTERSIC      M    PORTLAND    OR   36:42
# 7           [3    687       FRANCISCO MAYA      M    PORTLAND    OR   37:44
# 8           [4    623          PAUL MORROW      M   BEAVERTON    OR   38:34
# 9           [5    569      DEREK G OSBORNE      M   HILLSBORO    OR   39:21
#
#         7                8
# 0    None             None
# 1    None             None
# 2    None             None
# ...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                     2     3           4     5       6  \
# 0           ]   None                  None  None        None  None    None
# 1  Finishers:   577]                  None  None        None  None    None
# 2       Male:   414]                  None  None        None  None    None
# 3     Female:   163]                  None  None        None  None    None
# 4           ]   None                  None  None        None  None    None
# 5           1    814         JARED WILSON      M      TIGARD    OR   36:21
# 6           2    573   NATHAN A SUSTERSIC      M    PORTLAND    OR   36:42
# 7           3    687       FRANCISCO MAYA      M    PORTLAND    OR   37:44
# 8           4    623          PAUL MORROW      M   BEAVERTON    OR   38:34
# 9           5    569      DEREK G OSBORNE      M   HILLSBORO    OR   39:21
#
#         7                8
# 0    None             None
# 1    None             None
# 2    None             None
# 3    None             None
# ...

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Time, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Time, ...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#         0     1      2        3      4       5      6          7       8
# 0  [Place   Bib   Name   Gender   City   State   Time   Gun Time   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#             0      1                     2        3           4       5  \
# 0      [Place    Bib                  Name   Gender        City   State
# 0           ]   None                  None     None        None    None
# 1  Finishers:   577]                  None     None        None    None
# 2       Male:   414]                  None     None        None    None
# 3     Female:   163]                  None     None        None    None
# 4           ]   None                  None     None        None    None
# 5           1    814         JARED WILSON         M      TIGARD      OR
# 6           2    573   NATHAN A SUSTERSIC         M    PORTLAND      OR
# 7           3    687       FRANCISCO MAYA         M    PORTLAND      OR
# 8           4    623          PAUL MORROW         M   BEAVERTON      OR
#
#         6          7                8
# 0    Time   Gun Time            Team]
# 0    None       None             None
# 1    None       None             None
# ...

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   State   Time   Gun Time   Team]
# 0      [Place    Bib   Name   Gender   City   State   Time   Gun Time   Team]
# 0           ]   None   None     None   None    None   None       None    None
# 1  Finishers:   577]   None     None   None    None   None       None    None
# 2       Male:   414]   None     None   None    None   None       None    None
# 3     Female:   163]   None     None   None    None   None       None    None

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 0 to 581
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   [Place     583 non-null    object
#  1    Bib       581 non-null    object
#  2    Name      578 non-null    object
#  3    Gender    578 non-null    object
#  4    City      578 non-null    object
#  5    State     578 non-null    object
#  6    Time      578 non-null    object
#  7    Gun Time  578 non-null    object
#  8    Team]     578 non-null    object
# dtypes: object(9)
# memory usage: 45.5+ KB
# (583, 9)

# %%
df6 = df5.dropna(axis=0, how='any')
df6.info()
df6.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578 entries, 0 to 581
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   [Place     578 non-null    object
#  1    Bib       578 non-null    object
#  2    Name      578 non-null    object
#  3    Gender    578 non-null    object
#  4    City      578 non-null    object
#  5    State     578 non-null    object
#  6    Time      578 non-null    object
#  7    Gun Time  578 non-null    object
#  8    Team]     578 non-null    object
# dtypes: object(9)
# memory usage: 45.2+ KB
# (578, 9)

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                  Name  Gender        City  State    Time  \
# 5      1   814         JARED WILSON        M      TIGARD     OR   36:21
# 6      2   573   NATHAN A SUSTERSIC        M    PORTLAND     OR   36:42
# 7      3   687       FRANCISCO MAYA        M    PORTLAND     OR   37:44
# 8      4   623          PAUL MORROW        M   BEAVERTON     OR   38:34
# 9      5   569      DEREK G OSBORNE        M   HILLSBORO     OR   39:21
#
#    Gun Time            Team]
# 5     36:24                ]
# 6     36:45   INTEL TEAM F ]
# 7     37:48                ]
# 8     38:37                ]
# 9     39:24   INTEL TEAM F ]

# %%
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
#   Place   Bib                  Name  Gender        City  State    Time  \
# 5     1   814         JARED WILSON        M      TIGARD     OR   36:21
# 6     2   573   NATHAN A SUSTERSIC        M    PORTLAND     OR   36:42
# 7     3   687       FRANCISCO MAYA        M    PORTLAND     OR   37:44
# 8     4   623          PAUL MORROW        M   BEAVERTON     OR   38:34
# 9     5   569      DEREK G OSBORNE        M   HILLSBORO     OR   39:21
#
#    Gun Time             Team
# 5     36:24                ]
# 6     36:45   INTEL TEAM F ]
# 7     37:48                ]
# 8     38:37                ]
# 9     39:24   INTEL TEAM F ]

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7.head()
# Out:
#   Place   Bib                  Name  Gender        City  State    Time  \
# 5     1   814         JARED WILSON        M      TIGARD     OR   36:21
# 6     2   573   NATHAN A SUSTERSIC        M    PORTLAND     OR   36:42
# 7     3   687       FRANCISCO MAYA        M    PORTLAND     OR   37:44
# 8     4   623          PAUL MORROW        M   BEAVERTON     OR   38:34
# 9     5   569      DEREK G OSBORNE        M   HILLSBORO     OR   39:21
#
#    Gun Time            Team
# 5     36:24
# 6     36:45   INTEL TEAM F
# 7     37:48
# 8     38:37
# 9     39:24   INTEL TEAM F

# %%
time_list = df7[' Time'].tolist()
time_mins = []

for i in time_list:
    if isinstance(i, str) and ':' in i:
        try:
            m, s = i.strip().split(':')
            total_mins = int(m) + int(s)/60
            time_mins.append(round(total_mins, 2))
        except ValueError:
            time_mins.append(None)
    else:
        time_mins.append(None)

df7['Runner_mins'] = time_mins
df7.head()
# Out:
#   Place   Bib                  Name  Gender        City  State    Time  \
# 5     1   814         JARED WILSON        M      TIGARD     OR   36:21
# 6     2   573   NATHAN A SUSTERSIC        M    PORTLAND     OR   36:42
# 7     3   687       FRANCISCO MAYA        M    PORTLAND     OR   37:44
# 8     4   623          PAUL MORROW        M   BEAVERTON     OR   38:34
# 9     5   569      DEREK G OSBORNE        M   HILLSBORO     OR   39:21
#
#    Gun Time            Team  Runner_mins
# 5     36:24                        36.35
# 6     36:45   INTEL TEAM F         36.70
# 7     37:48                        37.73
# 8     38:37                        38.57
# 9     39:24   INTEL TEAM F         39.35

# %%
df7.describe(include=[np.number])
# Out:
#        Runner_mins
# count   306.000000
# mean     51.112745
# std       5.436028
# min      36.350000
# 25%      47.007500
# 50%      51.315000
# 75%      55.365000
# max      59.920000

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5


df7.boxplot(column='Runner_mins')
plt.grid(True, axis='y')
plt.ylabel('Chip Time')
plt.xticks([1], ['Runners'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f636f8fd910>], [Text(1, 0, 'Runners')])

# %%
x = df7['Runner_mins']
ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# <ipython-input-59-62931c2a3d35>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})

# %%
f_fuko = df7.loc[df7[' Gender']==' F']['Runner_mins']
m_fuko = df7.loc[df7[' Gender']==' M']['Runner_mins']
sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
plt.legend()
# Out:
# <ipython-input-60-c9cef76b4095>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
# <ipython-input-60-c9cef76b4095>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g_stats = df7.groupby(" Gender", as_index=True).describe()
print(g_stats)
# Out:
#         Runner_mins                                                        \
#               count       mean       std    min      25%     50%      75%
#  Gender
# F              52.0  53.806346  5.041117  43.77  49.3100  54.275  58.5975
# M             254.0  50.561299  5.357678  36.35  46.7175  50.925  54.8150
#
#
#            max
#  Gender
# F        59.92
# M        59.88

# %%
df7.boxplot(column='Runner_mins', by=' Gender')
plt.ylabel('Chip Time')
plt.suptitle("")
# Out:
# Text(0.5, 0.98, '')
